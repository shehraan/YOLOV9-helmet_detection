# %% [markdown]
# ## Complete Initial Setup

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Clone and Install

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Counting objects: 100% (218/218), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 325 (delta 159), reused 156 (delta 156), pack-reused 107
# Receiving objects: 100% (325/325), 2.23 MiB | 16.46 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 39.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 47.0 MB/s eta 0:00:00

# %%
# !nvidia-smi
# Out:
# Mon Jun 17 16:51:22 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !pip install -q roboflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.7 MB/s eta 0:00:00
# WARNING: The candidate selected for download or install is a yanked version: 'opencv-python-headless' candidate (version 4.8.0.74 at https://files.pythonhosted.org/packages/76/02/f128517f3ade4bb5f71e2afd8461dba70e3f466ce745fa1fd1fade9ad1b7/opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/opencv-python-headless/) (requires-python:>=3.6))
# Reason for being yanked: deprecated, use 4.8.0.76

# %% [markdown]
# ## Download model weights

# %% [markdown]
# **NOTE:** In the YOLOv9 paper, versions `yolov9-s` and `yolov9-m` are also mentioned, but the weights for these models are not yet available in the YOLOv9 [repository](https://github.com/WongKinYiu/yolov9).

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !ls -la {HOME}/weights
# Out:
# total 402440
# drwxr-xr-x 2 root root      4096 Jun 17 16:51 .
# drwxr-xr-x 1 root root      4096 Jun 17 16:51 ..
# -rw-r--r-- 1 root root  51508261 Feb 18 12:36 gelan-c.pt
# -rw-r--r-- 1 root root 117203713 Feb 18 12:36 gelan-e.pt
# -rw-r--r-- 1 root root 103153312 Feb 18 12:36 yolov9-c.pt
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt

# %% [markdown]
# ## Authenticate and Download the Dataset

# %% [markdown]
# **NOTE:** The dataset must be saved inside the `{HOME}/yolov9` directory, otherwise, the training will not succeed.

# %%
# %cd {HOME}/yolov9
# Out:
# /content/yolov9

# %% [markdown]
# **NOTE:** In this tutorial, I will use the [football-players-detection](https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc) dataset. Feel free to replace it with your dataset in YOLO format or use another dataset available on [Roboflow Universe](https://universe.roboflow.com). Additionally, if you plan to deploy your model to Roboflow after training, make sure you are the owner of the dataset and that no model is associated with the version of the dataset you are going to training on.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="p88mpGsDIB2BHFI3bxw1")
project = rf.workspace("sheeshyma").project("helmets-am2sf")
version = project.version(2)
dataset = version.download("yolov9")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.1.32)
# Requirement already satisfied: certifi==2023.7.22 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.25.2)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.4)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.4.27)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.53.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Helmets-1 to yolov9:: 100%|██████████| 135782/135782 [00:04<00:00, 29991.01it/s]
# Extracting Dataset Version Zip to Helmets-1 in yolov9:: 100%|██████████| 3852/3852 [00:00<00:00, 4816.25it/s]

# %% [markdown]
# ## Train Custom Model

# %%
# %cd {HOME}/yolov9
#epochs were prev. 25. Change that to 200 for implementation
# !python train.py \
--batch 18 --epochs 2 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data {dataset.location}/data.yaml \
--weights {HOME}/weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# /content/yolov9
# 2024-06-17 16:55:49.282485: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-17 16:55:49.282544: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-17 16:55:49.283886: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-17 16:55:49.291091: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-17 16:55:50.510680: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# train: weights=/content/weights/gelan-c.pt, cfg=models/detect/gelan-c.yaml, data=/content/yolov9/Helmets-1/data.yaml, hyp=hyp.scratch-high.yaml, epochs=2, batch_size=18, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, cls_pw=1.0, dfl=1.5, obj_pw=1.0, iou_t=0.2, anchor_t=5.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLO 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLO 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    212864  models.common.RepNCSPELAN4              [128, 256, 128, 64, 1]
#   3                -1  1    164352  models.common.ADown                     [256, 256]
#   4                -1  1    847616  models.common.RepNCSPELAN4              [256, 512, 256, 128, 1]
#   5                -1  1    656384  models.common.ADown                     [512, 512]
#   6                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   7                -1  1    656384  models.common.ADown                     [512, 512]
#   8                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   9                -1  1    656896  models.common.SPPELAN                   [512, 512, 256]
#  10                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  11           [-1, 6]  1         0  models.common.Concat                    [1]
#  12                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 4]  1         0  models.common.Concat                    [1]
#  15                -1  1    912640  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 1]
#  16                -1  1    164352  models.common.ADown                     [256, 256]
#  17          [-1, 12]  1         0  models.common.Concat                    [1]
#  18                -1  1   2988544  models.common.RepNCSPELAN4              [768, 512, 512, 256, 1]
#  19                -1  1    656384  models.common.ADown                     [512, 512]
#  20           [-1, 9]  1         0  models.common.Concat                    [1]
#  21                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  22      [15, 18, 21]  1   5491411  models.yolo.DDetect                     [1, [256, 512, 512]]
# gelan-c summary: 621 layers, 25437843 parameters, 25437827 gradients, 103.2 GFLOPs
#
# Transferred 931/937 items from /content/weights/gelan-c.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 154 weight(decay=0.0), 161 weight(decay=0.0005625000000000001), 160 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/yolov9/Helmets-1/train/labels.cache... 1680 images, 0 backgrounds, 0 corrupt: 100% 1680/1680 [00:00<?, ?it/s]
# val: Scanning /content/yolov9/Helmets-1/valid/labels.cache... 160 images, 0 backgrounds, 0 corrupt: 100% 160/160 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Plotting labels to runs/train/exp3/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp3
# Starting training for 2 epochs...
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         0/1      14.2G      1.695      1.959      1.339         27        640: 100% 94/94 [01:44<00:00,  1.11s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:05<00:00,  1.14s/it]
#                    all        160        524      0.634      0.631      0.613      0.274
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/1      12.4G      1.541      1.079      1.201         31        640: 100% 94/94 [01:29<00:00,  1.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:03<00:00,  1.25it/s]
#                    all        160        524      0.646      0.615      0.625      0.287
#
# 2 epochs completed in 0.058 hours.
# Optimizer stripped from runs/train/exp3/weights/last.pt, saved as runs/train/exp3/weights/last_striped.pt, 51.5MB
# Optimizer stripped from runs/train/exp3/weights/best.pt, saved as runs/train/exp3/weights/best_striped.pt, 51.5MB
#
# Validating runs/train/exp3/weights/best.pt...
# Fusing layers...
# gelan-c summary: 467 layers, 25411731 parameters, 0 gradients, 102.5 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:07<00:00,  1.59s/it]
#                    all        160        524      0.644      0.615      0.625      0.287
# Results saved to runs/train/exp3

# %% [markdown]
# ## Examine Training Results

# %% [markdown]
# **NOTE:** By default, the results of each subsequent training sessions are saved in `{HOME}/yolov9/runs/train/`, in directories named `exp`, `exp2`, `exp3`, ... You can override this behavior by using the `--name` parameter.

# %%
# !ls {HOME}/yolov9/runs/train/exp3/
# Out:
# events.out.tfevents.1718643269.cf9033900395.2676.0  labels.jpg	      train_batch1.jpg
# hyp.yaml					    opt.yaml	      train_batch2.jpg
# labels_correlogram.jpg				    train_batch0.jpg  weights

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp3/results.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp3/confusion_matrix.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp3/val_batch0_pred.jpg", width=1000)

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}/yolov9

# !python val.py \
--img 640 --batch 32 --conf 0.001 --iou 0.7 --device 0 \
--data {dataset.location}/data.yaml \
--weights {HOME}/yolov9/runs/train/exp3/weights/best.pt
# Out:
# /content/yolov9
# val: data=/content/yolov9/Helmets-1/data.yaml, weights=['/content/yolov9/runs/train/exp3/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False, min_items=0
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25411731 parameters, 0 gradients, 102.5 GFLOPs
# val: Scanning /content/yolov9/Helmets-1/valid/labels.cache... 160 images, 0 backgrounds, 0 corrupt: 100% 160/160 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:09<00:00,  1.90s/it]
#                    all        160        524      0.644      0.616      0.627      0.287
# Speed: 0.5ms pre-process, 34.8ms inference, 6.2ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val/exp

# %% [markdown]
# ## Inference with Custom Model

# %%
# !python detect.py \
--img 1280 --conf 0.1 --device 0 \
--weights {HOME}/yolov9/runs/train/exp3/weights/best.pt \
--source {dataset.location}/test/images
# Out:
# detect: weights=['/content/yolov9/runs/train/exp3/weights/best.pt'], source=/content/yolov9/Helmets-1/test/images, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25411731 parameters, 0 gradients, 102.5 GFLOPs
# image 1/80 /content/yolov9/Helmets-1/test/images/010c9b83a304d624_jpg.rf.9220473ec8fa876930720e655f556ce3.jpg: 1280x1280 1 Bicycle-helmet, 110.4ms
# image 2/80 /content/yolov9/Helmets-1/test/images/013d69c9848c9ff1_jpg.rf.b2a36f7948722e67f17093358525fcc8.jpg: 1280x1280 1 Bicycle-helmet, 103.8ms
# image 3/80 /content/yolov9/Helmets-1/test/images/024a37cbf86d9d89_jpg.rf.9d6b171e809475d12b4f662303e6e0e8.jpg: 1280x1280 6 Bicycle-helmets, 105.0ms
# image 4/80 /content/yolov9/Helmets-1/test/images/02e13c5a598d3132_jpg.rf.bd9ae8b21aa768f8352d7b07ce8ef518.jpg: 1280x1280 1 Bicycle-helmet, 104.4ms
# image 5/80 /content/yolov9/Helmets-1/test/images/03aba81c29e4d120_jpg.rf.0fbd88c85d6b1c8aa0ba66662063945f.jpg: 1280x1280 3 Bicycle-helmets, 105.3ms
# image 6/80 /content/yolov9/Helmets-1/test/images/058cadfc297497b0_jpg.rf.9391c6a6bbd589dae6951b2fa8edb149.jpg: 1280x1280 8 Bicycle-helmets, 105.6ms
# image 7/80 /content/yolov9/Helmets-1/test/images/05bd07f2c6084ac2_jpg.rf.7f06ba723da45776340717028fa0be9f.jpg: 1280x1280 3 Bicycle-helmets, 103.9ms
# image 8/80 /content/yolov9/Helmets-1/test/images/0dc7eb6e7c41ee2b_jpg.rf.49c74fe107d72c9d8912f8173182b9fe.jpg: 1280x1280 6 Bicycle-helmets, 104.4ms
# image 9/80 /content/yolov9/Helmets-1/test/images/0eaf9a33e057d510_jpg.rf.1d75c7c0f75c5e213b8bb7bb36759b55.jpg: 1280x1280 1 Bicycle-helmet, 105.4ms
# image 10/80 /content/yolov9/Helmets-1/test/images/11c94043a4bf7382_jpg.rf.9ad9f4b01fad09e8a60662fb20936fbf.jpg: 1280x1280 4 Bicycle-helmets, 105.6ms
# image 11/80 /content/yolov9/Helmets-1/test/images/13aeebe4cb040350_jpg.rf.39179348ec70d38e77f6385b10735aa2.jpg: 1280x1280 1 Bicycle-helmet, 105.3ms
# image 12/80 /content/yolov9/Helmets-1/test/images/1990cd763b2e1e7e_jpg.rf.5a8fcd20f5d1d581051a6b9ca705cd82.jpg: 1280x1280 2 Bicycle-helmets, 105.1ms
# image 13/80 /content/yolov9/Helmets-1/test/images/21828837781490ca_jpg.rf.ded4bc5b106b858c2afb7b90d5747293.jpg: 1280x1280 1 Bicycle-helmet, 105.2ms
# image 14/80 /content/yolov9/Helmets-1/test/images/21c8775f41a2cc29_jpg.rf.eb882528e28dbec3cd5c8473a1a4492a.jpg: 1280x1280 2 Bicycle-helmets, 105.1ms
# image 15/80 /content/yolov9/Helmets-1/test/images/23e9f7888c85ce04_jpg.rf.717893c8c439d38776e4bd3a696c2fba.jpg: 1280x1280 2 Bicycle-helmets, 100.8ms
# image 16/80 /content/yolov9/Helmets-1/test/images/256156ebea9a8f96_jpg.rf.a460d5a59db671649303d8d568e47cb9.jpg: 1280x1280 3 Bicycle-helmets, 106.9ms
# image 17/80 /content/yolov9/Helmets-1/test/images/30bc898f57cb8af3_jpg.rf.6a39a9ef2c9bb2ab502970ce16f04042.jpg: 1280x1280 4 Bicycle-helmets, 105.7ms
# image 18/80 /content/yolov9/Helmets-1/test/images/32490d7da76e3c55_jpg.rf.d3b3fae9b2098f747faa9e2e5e0b80e1.jpg: 1280x1280 8 Bicycle-helmets, 105.6ms
# image 19/80 /content/yolov9/Helmets-1/test/images/332f48fc66f296f9_jpg.rf.adbfb4cc208a8c63b48642edf87121fc.jpg: 1280x1280 1 Bicycle-helmet, 104.6ms
# image 20/80 /content/yolov9/Helmets-1/test/images/3527bac8e600842a_jpg.rf.5bdfe67a960de89d797cdf15e0f9ded3.jpg: 1280x1280 4 Bicycle-helmets, 105.6ms
# image 21/80 /content/yolov9/Helmets-1/test/images/372762903dcca7fd_jpg.rf.897081cacbe95e0f1d106dac66660917.jpg: 1280x1280 8 Bicycle-helmets, 104.3ms
# image 22/80 /content/yolov9/Helmets-1/test/images/39dd0711b36d0ac1_jpg.rf.06f1e332c59f57833b843aef6bb4e6c3.jpg: 1280x1280 1 Bicycle-helmet, 106.4ms
# image 23/80 /content/yolov9/Helmets-1/test/images/3b6512af7828bc45_jpg.rf.c816b5343ba5041b6b5037fd78b22eb5.jpg: 1280x1280 1 Bicycle-helmet, 104.9ms
# image 24/80 /content/yolov9/Helmets-1/test/images/3bf735cee2116494_jpg.rf.6fe8aebddeedbb2ca71afcb98fe6cd47.jpg: 1280x1280 1 Bicycle-helmet, 105.6ms
# image 25/80 /content/yolov9/Helmets-1/test/images/41add84a2048d9b9_jpg.rf.9cf6c9529255cb359cc3ea1ecc08c7e5.jpg: 1280x1280 2 Bicycle-helmets, 105.5ms
# image 26/80 /content/yolov9/Helmets-1/test/images/4421969f61e42608_jpg.rf.15b9936252d56ae0232d8c03971b4a97.jpg: 1280x1280 1 Bicycle-helmet, 105.4ms
# image 27/80 /content/yolov9/Helmets-1/test/images/47f92bc25d1b6447_jpg.rf.76b2d72ca48f842b45ad49b108aa66db.jpg: 1280x1280 7 Bicycle-helmets, 106.2ms
# image 28/80 /content/yolov9/Helmets-1/test/images/47ff14f75f7e7a9b_jpg.rf.e28a052b04f0cbb9f4463989f422195b.jpg: 1280x1280 36 Bicycle-helmets, 104.8ms
# image 29/80 /content/yolov9/Helmets-1/test/images/48f7fac9df533356_jpg.rf.b90af93b365c0491e963bc07a565e00b.jpg: 1280x1280 9 Bicycle-helmets, 105.3ms
# image 30/80 /content/yolov9/Helmets-1/test/images/4b9d93ab8eb3f544_jpg.rf.60f6421a46ac8029cd34f40e65582e62.jpg: 1280x1280 5 Bicycle-helmets, 104.4ms
# image 31/80 /content/yolov9/Helmets-1/test/images/5630bffa5ac2033c_jpg.rf.e120f5c76285bee5a1120cff4f9b9db0.jpg: 1280x1280 2 Bicycle-helmets, 104.1ms
# image 32/80 /content/yolov9/Helmets-1/test/images/570b1a9934f61919_jpg.rf.7cdea99de5449147c3e3c7f96872fa71.jpg: 1280x1280 2 Bicycle-helmets, 105.3ms
# image 33/80 /content/yolov9/Helmets-1/test/images/622eea5eb3c6b0fd_jpg.rf.dc3d2abe3ae533ca239fc3881d2f9691.jpg: 1280x1280 3 Bicycle-helmets, 104.6ms
# image 34/80 /content/yolov9/Helmets-1/test/images/62b081a9d8987f45_jpg.rf.9146d10e305a16209a5ce735800590b3.jpg: 1280x1280 2 Bicycle-helmets, 105.9ms
# image 35/80 /content/yolov9/Helmets-1/test/images/68a7b2a28150afa5_jpg.rf.92a4edd5206b710dc0e27ae99265d252.jpg: 1280x1280 2 Bicycle-helmets, 104.8ms
# image 36/80 /content/yolov9/Helmets-1/test/images/6b0d23dbc89aa568_jpg.rf.3820dfd9c04c340d1978c016e9889ad8.jpg: 1280x1280 4 Bicycle-helmets, 105.9ms
# image 37/80 /content/yolov9/Helmets-1/test/images/6b90dae8a3e7017d_jpg.rf.3b1cd686989fae9464868346efbfb39b.jpg: 1280x1280 2 Bicycle-helmets, 105.8ms
# image 38/80 /content/yolov9/Helmets-1/test/images/6dc0f95b3110b688_jpg.rf.8cd78b30b41af0498e33ca17c8339642.jpg: 1280x1280 7 Bicycle-helmets, 105.8ms
# image 39/80 /content/yolov9/Helmets-1/test/images/71a2d9f921f1bc3c_jpg.rf.9bcaf2bdc6369f188cff8013c087a4af.jpg: 1280x1280 3 Bicycle-helmets, 106.7ms
# image 40/80 /content/yolov9/Helmets-1/test/images/71d771ce5566de95_jpg.rf.66bf87e98e157a5a7de11be392323605.jpg: 1280x1280 3 Bicycle-helmets, 105.4ms
# image 41/80 /content/yolov9/Helmets-1/test/images/77fafe329d0d0e88_jpg.rf.03820c05585c02beec1e945969ef0b67.jpg: 1280x1280 2 Bicycle-helmets, 105.2ms
# image 42/80 /content/yolov9/Helmets-1/test/images/7ca595c32a61f9bb_jpg.rf.3d63efdaae4e8731a4dd7ae07bc902e4.jpg: 1280x1280 1 Bicycle-helmet, 106.6ms
# image 43/80 /content/yolov9/Helmets-1/test/images/7d1e763087a356fc_jpg.rf.c5da501e18ad353e07b261a9508eee18.jpg: 1280x1280 17 Bicycle-helmets, 105.0ms
# image 44/80 /content/yolov9/Helmets-1/test/images/874cf62592ea13ca_jpg.rf.45b35a3af653cdcdb79b75ae8ececefb.jpg: 1280x1280 3 Bicycle-helmets, 105.6ms
# image 45/80 /content/yolov9/Helmets-1/test/images/87bef3011b8cf5d1_jpg.rf.24addc21b27e724bdabd5f4adb2be0e2.jpg: 1280x1280 21 Bicycle-helmets, 106.0ms
# image 46/80 /content/yolov9/Helmets-1/test/images/88548df746a381ea_jpg.rf.b784474f1761bd4bd81cc0a2dc04fa48.jpg: 1280x1280 4 Bicycle-helmets, 104.1ms
# image 47/80 /content/yolov9/Helmets-1/test/images/897d7c13cf06730f_jpg.rf.8f8c8c529d4742bb83b55e168b7af780.jpg: 1280x1280 3 Bicycle-helmets, 106.0ms
# image 48/80 /content/yolov9/Helmets-1/test/images/8baf0736f2957f4e_jpg.rf.0ceffed6cda060bdc48b555187ee7074.jpg: 1280x1280 1 Bicycle-helmet, 106.0ms
# image 49/80 /content/yolov9/Helmets-1/test/images/8e076f9d8996ee0b_jpg.rf.e8445d49ca5c0a0979bcd78185fe06d6.jpg: 1280x1280 3 Bicycle-helmets, 105.8ms
# image 50/80 /content/yolov9/Helmets-1/test/images/8f4ccfe212d12fee_jpg.rf.1c90fc574bb9864219907efc7d030c39.jpg: 1280x1280 7 Bicycle-helmets, 105.7ms
# image 51/80 /content/yolov9/Helmets-1/test/images/90ac0423dc502d1c_jpg.rf.68a1b00c6a481ee0d2b3ed682ceb77fd.jpg: 1280x1280 7 Bicycle-helmets, 106.3ms
# image 52/80 /content/yolov9/Helmets-1/test/images/90b48724712c2e08_jpg.rf.c0c9e5ab5d35396524d45d0e6d08052d.jpg: 1280x1280 4 Bicycle-helmets, 106.4ms
# image 53/80 /content/yolov9/Helmets-1/test/images/918314c670b2e13a_jpg.rf.bf4e46db0351e4b9aaa8e7a4ee4ab854.jpg: 1280x1280 2 Bicycle-helmets, 105.3ms
# image 54/80 /content/yolov9/Helmets-1/test/images/945f6cd6da0eff83_jpg.rf.8de27f3baa68a2b849199b20ad87d94a.jpg: 1280x1280 3 Bicycle-helmets, 105.1ms
# image 55/80 /content/yolov9/Helmets-1/test/images/9ac7ea16eed3fde9_jpg.rf.4f75045f3ac55cc50fa5d4362dc47358.jpg: 1280x1280 4 Bicycle-helmets, 105.3ms
# image 56/80 /content/yolov9/Helmets-1/test/images/ac1abecbfea42693_jpg.rf.a809885bc581b08f20bfd564d2d94b51.jpg: 1280x1280 4 Bicycle-helmets, 105.8ms
# image 57/80 /content/yolov9/Helmets-1/test/images/ae48d7555399f3b4_jpg.rf.1c2f7ef30f862ce8838694aa2dfdff53.jpg: 1280x1280 1 Bicycle-helmet, 106.2ms
# image 58/80 /content/yolov9/Helmets-1/test/images/af506a37871ba8ca_jpg.rf.486b6780aca1e19a974c7dcc09b104df.jpg: 1280x1280 1 Bicycle-helmet, 104.3ms
# image 59/80 /content/yolov9/Helmets-1/test/images/b313ee89fc7db9f0_jpg.rf.d93f1a7fd590827bd84f742b09490ef7.jpg: 1280x1280 1 Bicycle-helmet, 105.4ms
# image 60/80 /content/yolov9/Helmets-1/test/images/b44889560e203771_jpg.rf.a704ad6f161654b5d76c41c73e322283.jpg: 1280x1280 18 Bicycle-helmets, 104.2ms
# image 61/80 /content/yolov9/Helmets-1/test/images/bc18a5e75c1d05d8_jpg.rf.9ac7602401ee968713d25637d56153c4.jpg: 1280x1280 2 Bicycle-helmets, 105.0ms
# image 62/80 /content/yolov9/Helmets-1/test/images/c0c1a85ab4201093_jpg.rf.da1ddd709ef2c7e2543378dfaa13be65.jpg: 1280x1280 4 Bicycle-helmets, 105.7ms
# image 63/80 /content/yolov9/Helmets-1/test/images/c70ed344779dcd21_jpg.rf.6f0c5a435e11a7f8fbf0550e4954f1f7.jpg: 1280x1280 1 Bicycle-helmet, 106.0ms
# image 64/80 /content/yolov9/Helmets-1/test/images/c86589df92ff010c_jpg.rf.f6dd2a50af3a239656f32364cd51c111.jpg: 1280x1280 2 Bicycle-helmets, 106.9ms
# image 65/80 /content/yolov9/Helmets-1/test/images/c8934826668608c9_jpg.rf.a37fc0287e7de05c811b464885dbfb39.jpg: 1280x1280 1 Bicycle-helmet, 106.8ms
# image 66/80 /content/yolov9/Helmets-1/test/images/cabd85812bb4517d_jpg.rf.afcb5c4d1c4a5d2c4d1ac481ac0b8b7b.jpg: 1280x1280 4 Bicycle-helmets, 105.5ms
# image 67/80 /content/yolov9/Helmets-1/test/images/ccb3f4259b798cd1_jpg.rf.22485d4f62378820e31a2584425ccb4b.jpg: 1280x1280 1 Bicycle-helmet, 104.6ms
# image 68/80 /content/yolov9/Helmets-1/test/images/ce47d4427c3f6ce9_jpg.rf.9a0184de127762dd5023d3032ad2a106.jpg: 1280x1280 7 Bicycle-helmets, 105.0ms
# image 69/80 /content/yolov9/Helmets-1/test/images/cfbfd5133d7ff63d_jpg.rf.c28fa6538ed9e041d749a5a837ae65b8.jpg: 1280x1280 3 Bicycle-helmets, 105.4ms
# image 70/80 /content/yolov9/Helmets-1/test/images/d2a8a142596f9a15_jpg.rf.6b1317f22742767ebb7ea8dfc8525beb.jpg: 1280x1280 9 Bicycle-helmets, 104.6ms
# image 71/80 /content/yolov9/Helmets-1/test/images/d53aaefb42a864ae_jpg.rf.26ad29e2d98e4d742edc9d9a12b22727.jpg: 1280x1280 16 Bicycle-helmets, 106.1ms
# image 72/80 /content/yolov9/Helmets-1/test/images/d66601fa2c8778e4_jpg.rf.657f381472d95a9ea6b8d517cd98792c.jpg: 1280x1280 2 Bicycle-helmets, 105.0ms
# image 73/80 /content/yolov9/Helmets-1/test/images/deea56ac8e8f6eed_jpg.rf.d36311fbf2a4a90ea88b0e3bec0ed8f2.jpg: 1280x1280 5 Bicycle-helmets, 105.6ms
# image 74/80 /content/yolov9/Helmets-1/test/images/dfc5209e076adffd_jpg.rf.06fec912ed4f7ae806fd1830872b540c.jpg: 1280x1280 5 Bicycle-helmets, 105.7ms
# image 75/80 /content/yolov9/Helmets-1/test/images/ed57781cec9680a3_jpg.rf.f30d41484e23ef3339736e9c8577704f.jpg: 1280x1280 1 Bicycle-helmet, 105.8ms
# image 76/80 /content/yolov9/Helmets-1/test/images/eded9ce8a04a16b2_jpg.rf.69c5406dd17e6ef3733126e9aa384a96.jpg: 1280x1280 1 Bicycle-helmet, 105.7ms
# image 77/80 /content/yolov9/Helmets-1/test/images/f7beb219770f6c57_jpg.rf.c35ce8c88e233226efbb7e9d420602ac.jpg: 1280x1280 2 Bicycle-helmets, 106.0ms
# image 78/80 /content/yolov9/Helmets-1/test/images/f8adcdf5ea79724c_jpg.rf.62d66f3770e91e090826a2356a60004f.jpg: 1280x1280 5 Bicycle-helmets, 105.5ms
# image 79/80 /content/yolov9/Helmets-1/test/images/fad8f28999a08036_jpg.rf.3b43520011c9362c7c2f5338a221dc4e.jpg: 1280x1280 2 Bicycle-helmets, 105.0ms
# image 80/80 /content/yolov9/Helmets-1/test/images/fb5bddc0248eaa23_jpg.rf.c6a8f2e8f221c283df68d9ae3b12f0d9.jpg: 1280x1280 1 Bicycle-helmet, 106.1ms
# Speed: 1.8ms pre-process, 105.4ms inference, 8.8ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/exp2

# %% [markdown]
# **NOTE:** Just like behore, the inference results have been saved in the appropriate directory inside `{HOME}/yolov9/runs/detect/`. Let's examine few of those results.

# %%
import glob

from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/yolov9/runs/detect/exp3/*.jpg')[:2]:
      display(Image(filename=image_path, width=600))

# %% [markdown]
# ## BONUS: Deploy YOLOv9 Model with Inference

# %% [markdown]
# **NOTE:** To deploy the model and display inference results, we will need two additional packages - [`inference`](https://pypi.org/project/inference) and [`supervision`](https://pypi.org/project/supervision). Let's install and import them!

# %%
# !pip install -q inference supervision
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 414.0/414.0 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.0/124.0 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 17.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 12.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.0/252.0 kB 16.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.7/239.7 kB 25.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 32.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 31.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 940.0/940.0 kB 37.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 18.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 54.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 20.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.0/906.0 kB 49.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 39.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 66.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.9/143.9 kB 19.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 99.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 92.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.2/548.2 kB 36.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 11.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.4 MB/s eta 0:00:00
#   Building wheel for GPUtil (setup.py) ... done

# %%
import cv2
import random
import getpass

import supervision as sv

from inference import get_model

# %matplotlib inline

# %% [markdown]
# **NOTE:** Before using your model in Inference, you first need to upload your weights to Roboflow Universe. Ensure to specify the correct `model_type` - `yolov9`, and that the project version matches the version of the dataset you used for training, denoted by `[1]`. In my case, it's `6`.
#
# ![YOLOv9 Benchmark](https://storage.googleapis.com/com-roboflow-marketing/notebooks/examples/upload-roboflow-model.png)

# %%
version.deploy(model_type="yolov9", model_path=f"{HOME}/yolov9/runs/train/exp3")
# Out:
# An error occured when getting the model upload URL: This version already has a trained model. Please generate and train a new version in order to upload model to Roboflow.

# %% [markdown]
# **NOTE:** Now we can download our model anywhere using the assigned `model_id` denoted by `[2]`. In my case `football-players-detection-3zvbc/6`. To download the model you will need your [`ROBOFLOW_API_KEY`](https://docs.roboflow.com/api-reference/authentication).

# %%
ROBOFLOW_API_KEY = getpass.getpass()

model = get_model(model_id="helmets-am2sf/1", api_key=ROBOFLOW_API_KEY)
# Out:
# ··········

# %% [markdown]
# **NOTE:** Let's pick random image from our test subset and detect objects using newly fine-tuned model.

# %%
image_paths = sv.list_files_with_extensions(
    directory=f"{dataset.location}/test/images",
    extensions=['png', 'jpg', 'jpeg']
)
image_path = random.choice(image_paths)
image = cv2.imread(image_path)

result = model.infer(image, confidence=0.1)[0]
detections = sv.Detections.from_inference(result)

# %% [markdown]
# **NOTE:** Finally, let's use supervision and [annotate](https://supervision.roboflow.com/develop/annotators/) our results.

# %%
label_annotator = sv.LabelAnnotator(text_color=sv.Color.BLACK)
bounding_box_annotator = sv.BoundingBoxAnnotator()

annotated_image = image.copy()
annotated_image = bounding_box_annotator.annotate(scene=annotated_image, detections=detections)
annotated_image = label_annotator.annotate(scene=annotated_image, detections=detections)

sv.plot_image(annotated_image)
